# %% [markdown]
# # Functions

# %% [markdown]
# ### Example #1

# %%
def print_something():
   print("The students in this class are amazing.")

print_something()

# %% [markdown]
# ### Example #2

# %%
def double_num(num):
    print(f"The number {num} doubled is", num *2)

num = 2
double_num(num)

# %% [markdown]
# ### Example #3

# %%
def double_num(num):
    return num * 2

num = 2
num_doubled = double_num(num)
print(f"The number {num} doubled is", num_doubled)

# %% [markdown]
# ### Example #4

# %%
def print_something():
   print("80 % of a data scientists time is spent preparing the data T/F ?")

# %%
def print_something_else():
   print("Python is the language of choice for most data scientists. T/F")

# %%
def main():
   print_something()
   print_something_else()

# %%
main()

# %% [markdown]
# ### Note:
#
# To add URL
#  - Change cell to Code
#  - Add URL
#  - Change cell to Markdown
#  - Press Ctrl - Enter to activate link

# %% [markdown]
# ### Function Documentation

# %% [markdown]
# https://www.w3schools.com/python/python_functions.asp

# %% [markdown]
# https://docs.python.org/3/library/functions.html
