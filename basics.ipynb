# %% [markdown]
# ## Python Basics

# %% [markdown]
# ## Part 1: Arithmetic Operators

# %% [markdown]
# #### Problem 1.1
#
# Add the ints 3 and 2.

# %%
3 + 2           # COMPLETE THIS CODE

# %% [markdown]
# #### Problem 1.2
#
# Add 7.0 and 2.0.

# %%
7.0 + 2.0 # COMPLETE THIS CODE

# %% [markdown]
# #### Problem 1.3
#
# Divide 23 by 2.

# %%
23/2            # COMPLETE THIS CODE

# %% [markdown]
# #### Problem 1.4
#
# Multiply 24.0 and 25.4.

# %%
24 * 25.4          # COMPLETE THIS CODE

# %% [markdown]
# #### Problem 1.5
#
# **Independently**, add 13 and 27.

# %%
13 + 27 # COMPLETE THIS CODE

# %% [markdown]
# #### Problem 1.6
#
# **Independently**, multiply 1000 and 3000.5.

# %%
1000 * 3000.5 # COMPLETE THIS CODE

# %% [markdown]
# #### Problem 1.7
#
# **Independently**, divide 250 by 50.

# %%
250 / 50 # COMPLETE THIS CODE

# %% [markdown]
# ## Part 2: Variables

# %% [markdown]
# #### Problem 2.1
#
# **Independently**, look through the given declarations and determine which ones are incorrect:
#
# a. Var1 = 7
#
# b. VAR5 = 8
#
# c. 2var = 92 incorrect
#
# d. first_last_name = "james jaggard"
#
# e. Hello! = "0.283" incorrect
#
# f. variable24 = "my favorite food is"
#
# g. str = "string"

# %% [markdown]
# #### Problem 2.2
#
# Create a variable called `my_fav_song` and assign a string (anything inside quotes: "...") to it with your favorite song.
#
# **NOTE**: We will output the variable's value by writing the name of the variable on a line of its own.

# %%
my_fav_song = "All the Small Thinigs" # COMPLETE THIS CODE

my_fav_song

# %% [markdown]
# #### Problem 2.3
#
# Create and name a variable with the number of your siblings as an integer. Output its value.

# %%
num_siblings = 2 # COMPLETE THIS CODE
print(num_siblings) # COMPLETE THIS CODE

# %% [markdown]
# **Double Click This Cell To Enter Your Answer(s)**

# %% [markdown]
# ## Part 3: Debugging
#
#
# In this part, we will explore how to identify and correct errors in Python.

# %% [markdown]
# #### Problem 3.1
#
# Correct the error below.

# %%
favorite_fruit = "dragon fruit"

# %% [markdown]
# #### Problem 3.2
#
# Correct the line below based on what we most likely think it is intending to do.

# %%
x = 0
x = 2 * x
x = 2 ** x
x = 2 * x
x = x ** x

x

# %% [markdown]
# #### Problem 3.3
#
# Debug the code shown below such that it performs the intended mathematical operations.

# %%
x = 47
y = 3
z = x**y
print(z)

# %% [markdown]
# ## Part 4: Homework Practice [OPTIONAL]

# %% [markdown]
# ### Part 4.1: Arithmetic Operators

# %% [markdown]
# #### Problem 4.1.1
#
# Calculate 5 divided by 2.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# #### Problem 4.1.2
#
# Calculate 50 divided by 2.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# #### Problem 4.1.3
#
# Calculate 28 multiplied by 1995.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# #### Problem 4.1.4
#
# Calculate 3 squared.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# #### Problem 4.1.5
#
# Calculate 2 to the 10th power minus 5.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# #### Problem 4.1.6
#
# Write code that outputs the names of three different countries. **HINT**: You will need a new code cell for every output.

# %%
# COMPLETE THIS CODE

# %%
# COMPLETE THIS CODE

# %%
# COMPLETE THIS CODE

# %% [markdown]
# #### Problem 4.1.7
#
# Write code that outputs the result of multiplying 5 by 23.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# #### Problem 4.1.8
#
# Write code that outputs the result of raising 2 to the 100th power.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# #### Problem 4.1.9
#
# Calculate 50 multiplied by 4.5.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# #### Problem 4.1.10
#
# Calculate 50 multiplied by 4.5 plus 10.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# #### Problem 4.1.11
#
# Calculate 4 to the 8th power plus 10.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# ### Part 4.2: Variables

# %% [markdown]
# #### Problem 4.2.1
#
# Create a variable named favorite_animal and assign a string to it of your favorite animal. Output its value.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# #### Problem 4.2.2
#
# Create a variable called problem_number and assign the float 4.22 to it. Output its value.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# #### Problem 4.2.3
#
# Create a variable called next_problem_number and assign the result of adding problem_number and 0.01. Output its value.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# #### Problem 4.2.4
#
# Create a variable named my_age and assign an int with your age to it. Output its value.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# #### Problem 4.2.5
#
# Create a variable named my_age_in_months that is equal to my_age multiplied by 12. Output its value.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# #### Problem 4.2.6
#
# Write code that creates and outputs a variable called popular_name and assign to it the string James.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# #### Problem 4.2.7
#
# Create a variable birth_year and set it equal to the year you were born. Then output `"I was born in"` in the first cell and `birth_year` in the second cell.

# %%
# COMPLETE THIS CODE

# %%
# COMPLETE THIS CODE

# %% [markdown]
# #### Problem 4.2.8
#
# Create a variable `favorite_food` and assign to it a `string` with your favorite food. Output `'I love to eat'` in the first cell and `favorite_food` in the second cell.

# %%
# COMPLETE THIS CODE

# %%
# COMPLETE THIS CODE

# %% [markdown]
# #### Problem 4.2.9
#
# Modify the code to calculate the area of a rectangle whose length is 10 and width is 5.

# %%
length = 5
width = 4
area = length*width
area

# %% [markdown]
# #### Problem 4.2.10
#
# Modify the code to calculate the `cost_per_person` if the `total_cost` is 500.

# %%
total_cost = 100
number_of_people = 5
cost_per_person = total_cost/number_of_people
cost_per_person

# %% [markdown]
# #### Problem 4.2.11
#
# Modify the code shown below to calculate the final exam grade needed when:
#
# | Exam         	| Grade 	| Weight 	|
# |--------------	|-------	|--------	|
# | Exam 1:      	| 75    	| 0.2    	|
# | Exam 2:      	| 82    	| 0.2    	|
# | Final Exam:  	| ?     	| 0.6    	|
# | Final Grade: 	| 85    	|        	|

# %%
exam_1_grade = 90
exam_1_weight = 0.25

exam_2_grade = 84
exam_2_weight = 0.3

final_exam_weight = 0.45
wanted_final_grade = 90

required_grade_on_final = (wanted_final_grade - exam_1_grade * exam_1_weight - exam_2_grade * exam_2_weight)/final_exam_weight
required_grade_on_final

# %% [markdown]
# #### Problem 4.2.12
#
# Create a variable that stores the name of the country you live in. Output that variable.

# %%
# COMPLETE THIS CODE
# COMPLETE THIS CODE

# %% [markdown]
# #### Problem 4.2.13
#
# Create a variable named `height_cm` and set it equal to your height in centimeters. Output `height_cm`.
#
# <br>
#
# **NOTE**: 1 inch = 2.54 cm.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# #### Problem 4.2.14
#
# Create a variable named `height_m` and set it equal to your height in m. Use the `height_cm` variable from the previous problem. Output `height_m`.
#
# <br>
#
# **NOTE**: 1 m = 100 cm.

# %%
# COMPLETE THIS CODE

# %% [markdown]
# #### Problem 4.2.15
#
# Which of the following variables names would not run in python?

# %% [markdown]
# a.
# ```python
# 1var = 10
# ```
#
# b.
# ```python
# 2var = 20
# ```
#
# c.
# ```python
# 3_var = 30
# ```
#
# d.
# ```python
# Var4 = 40
# ```
#
# e.
# ```python
# VAR5 = 50
# ```
#
# f.
# ```python
# var_6 = 60
# ```
#
# g.
# ```python
# month&year = "July 2022"
# ```
#
# h.
# ```python
# hello = "hello"
# ```
#
# i.
# ```python
# for = "for"
# ```

# %% [markdown]
# #### Problem 4.2.16
#
# Create a variable `name` and assign it to your name. Output `name`. Then, reassign `name` to a friend's name. Output again.

# %%
# COMPLETE THIS CODE

# %%
# COMPLETE THIS CODE

# %% [markdown]
# ### Part 4.3: Debugging

# %% [markdown]
# #### Problem 4.3.1
#
# Debug the code shown below.

# %%
x = "17"
y = "3"
x * y

# %% [markdown]
# #### Problem 4.3.2
#
# Debug the code shown below.

# %%
#f(x) = ax^2 + bx + c
A = 1
B = 8
C = 15
x1 = (-b + (b**2 - 4 * a * c)**0.5)/(2 * a)
x2 = (-b - (b**2 - 4 * a * c)**0.5)/(2 * a)
print(x1)
print(x2)
# Out:
# -3.0
# -5.0

# %%
# COMPLETE THIS CODE
