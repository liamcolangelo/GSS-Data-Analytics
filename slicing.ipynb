# %% [markdown]
# # Slicing

# %%
countriesInAsia = ["China", "Indonesia", "South Korea", "Hong Kong", "Japan"]

# %% [markdown]
# ### Example #1

# %%
countriesInAsia[1]
# Out:
# '2'

# %% [markdown]
# ### Example #2

# %%
countriesInAsia[1:4]
# Out:
# ['2', '3', '4']

# %% [markdown]
# ### Example #3

# %%
countriesInAsia[1:]
# Out:
# ['2', '3', '4', '5']

# %% [markdown]
# ### Example #4

# %%
countriesInAsia[:2]
# Out:
# ['1', '2']

# %% [markdown]
# ### Example #5

# %%
countriesInAsia[::2]
# Out:
# ['1', '3', '5']

# %% [markdown]
# ### Note:
#
# To add URL
#  - Change cell to Code
#  - Add URL
#  - Change cell to Markdown
#  - Press Ctrl - Enter to activate link

# %%
### Slicing Documentation

# %% [markdown]
# https://towardsdatascience.com/the-basics-of-indexing-and-slicing-python-lists-2d12c90a94cf
